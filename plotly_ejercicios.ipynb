# %% [markdown]
# # Data Science Salaries 2023

# %% [markdown]
# Este conjunto de datos es útil para entender la distribución de los salarios en el campo de la ciencia de datos y cómo estos pueden variar en función de factores como la ubicación del empleado y del empleador, el nivel de experiencia, el tipo de empleo, entre otros. Nos permite explorar el impacto del trabajo remoto en los salarios de ciencia de datos y empezar a sacar nuestras propias conclusiones.

# %% [markdown]
# #### VARIABLES

# %% [markdown]
# <table>
#   <tr>
#     <th>Nombre de la columna</th>
#     <th>Descripción</th>
#   </tr>
#   <tr>
#     <td>work_year</td>
#     <td>El año en que se pagó el salario.</td>
#   </tr>
#   <tr>
#     <td>experience_level</td>
#     <td>El nivel de experiencia en el trabajo durante el año.</td>
#   </tr>
#   <tr>
#     <td>employment_type</td>
#     <td>El tipo de empleo para el rol.</td>
#   </tr>
#   <tr>
#     <td>job_title</td>
#     <td>El rol desempeñado durante el año.</td>
#   </tr>
#   <tr>
#     <td>salary</td>
#     <td>El total bruto del salario pagado.</td>
#   </tr>
#   <tr>
#     <td>salary_currency</td>
#     <td>La moneda del salario pagado como código de moneda ISO 4217.</td>
#   </tr>
#   <tr>
#     <td>salaryinusd</td>
#     <td>El salario en dólares estadounidenses (USD).</td>
#   </tr>
#   <tr>
#     <td>employee_residence</td>
#     <td>El principal país de residencia del empleado durante el año de trabajo como código de país ISO 3166.</td>
#   </tr>
#   <tr>
#     <td>remote_ratio</td>
#     <td>La cantidad total de trabajo realizado a distancia.</td>
#   </tr>
#   <tr>
#     <td>company_location</td>
#     <td>El país de la oficina principal del empleador o la sucursal contratante.</td>
#   </tr>
#   <tr>
#     <td>company_size</td>
#     <td>El número mediano de personas que trabajaron para la empresa durante el año.</td>
#   </tr>
# </table>

# %% [markdown]
# ### Objetivos:

# %% [markdown]
# El objetivo principal de este ejercicio es aprender y aplicar técnicas de análisis y visualización de datos utilizando las bibliotecas de Python Matplotlib, Seaborn y Plotly.
#
# Los pasos adecuados para completarlo son:
#
# 1. **Explorar el conjunto de datos**: Comprender la estructura del conjunto de datos, los tipos de variables presentes y cómo estas están distribuidas.
#    **Limpiar y preparar el conjunto de datos**: Manipular los datos para que sean más accesibles y útiles para el análisis. Esto puede incluir tratar con valores faltantes, convertir tipos de datos y generar nuevas variables a partir de las existentes.
#
# 2. **Analizar el conjunto de datos**: Extraer información útil y significativa del conjunto de datos a través de diversas técnicas de análisis de datos. </br>
#    **Visualizar los datos**: Crear gráficos y diagramas que ayuden a entender y comunicar los patrones y las relaciones presentes en los datos.
#
# Para responder a las preguntas planteadas se deben usar las siguientes bibliotecas :
#
# - Usar **Matplotlib** para crear gráficos básicos como gráficos de barras, de líneas y de dispersión.
# - Usar **Seaborn** para crear gráficos más complejos y atractivos visualmente, aprovechando sus capacidades de integración con pandas.
# - Usar **Plotly** para crear gráficos interactivos que permiten una exploración más profunda de los datos.

# %% [markdown]
# ### Primer paso, la carga de datos, limpieza, exploración y primera comprensión de nuestro dataset

# %% [markdown]
# #### Importamos las librerías necesarias:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# #### Cargamos nuestro dataset

# %%
df = pd.read_csv("salaries.csv")

# %%
df.head(15)
# Out:
#     work_year experience_level employment_type                 job_title  \
# 0        2023               SE              FT  Principal Data Scientist
# 1        2023               MI              CT               ML Engineer
# 2        2023               MI              CT               ML Engineer
# 3        2023               SE              FT            Data Scientist
# 4        2023               SE              FT            Data Scientist
# 5        2023               SE              FT         Applied Scientist
# 6        2023               SE              FT         Applied Scientist
# 7        2023               SE              FT            Data Scientist
# 8        2023               SE              FT            Data Scientist
# 9        2023               SE              FT            Data Scientist
# 10       2023               SE              FT            Data Scientist
# 11       2023               SE              FT              Data Analyst
# 12       2023               SE              FT              Data Analyst
# 13       2023               EN              FT         Applied Scientist
# 14       2023               EN              FT         Applied Scientist
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0    80000             EUR          85847                 ES           100
# 1    30000             USD          30000                 US           100
# 2    25500             USD          25500                 US           100
# 3   175000             USD         175000                 CA           100
# 4   120000             USD         120000                 CA           100
# 5   222200             USD         222200                 US             0
# 6   136000             USD         136000                 US             0
# 7   219000             USD         219000                 CA             0
# 8   141000             USD         141000                 CA             0
# 9   147100             USD         147100                 US             0
# 10   90700             USD          90700                 US             0
# 11  130000             USD         130000                 US           100
# 12  100000             USD         100000                 US           100
# 13  213660             USD         213660                 US             0
# 14  130760             USD         130760                 US             0
#
#    company_location company_size
# 0                ES            L
# 1                US            S
# 2                US            S
# 3                CA            M
# 4                CA            M
# 5                US            L
# 6                US            L
# 7                CA            M
# 8                CA            M
# 9                US            M
# 10               US            M
# 11               US            M
# 12               US            M
# 13               US            L
# 14               US            L

# %% [markdown]
# ¿Cuántas entradas (filas) y variables (columnas) tiene el conjunto de datos?

# %%
df.shape
# Out:
# (3755, 11)

# %% [markdown]
# ¿Qué tipos de datos contiene cada columna?

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# ¿Existen valores faltantes en el conjunto de datos?

# %%
df.duplicated().sum()
# Out:
# 1171

# %%
df.isnull().sum() / len(df) * 100
#df.isnull().sum()
#df.isnull().sum().sum()
#df.isnull()
# Out:
# work_year             0.0
# experience_level      0.0
# employment_type       0.0
# job_title             0.0
# salary                0.0
# salary_currency       0.0
# salary_in_usd         0.0
# employee_residence    0.0
# remote_ratio          0.0
# company_location      0.0
# company_size          0.0
# dtype: float64

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# #### ¿Cúal es la distribución que presentan las variables de nuestro dataset?

# %%
df.describe().T
# Out:
#                 count           mean            std     min       25%  \
# work_year      3755.0    2022.373635       0.691448  2020.0    2022.0
# salary         3755.0  190695.571771  671676.500508  6000.0  100000.0
# salary_in_usd  3755.0  137570.389880   63055.625278  5132.0   95000.0
# remote_ratio   3755.0      46.271638      48.589050     0.0       0.0
#
#                     50%       75%         max
# work_year        2022.0    2023.0      2023.0
# salary         138000.0  180000.0  30400000.0
# salary_in_usd  135000.0  175000.0    450000.0
# remote_ratio        0.0     100.0       100.0

# %% [markdown]
# #### Crea una gráfica para visualizar nuestras variables numéricas:

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
 
cols = ['work_year', 'salary', 'salary_in_usd', 'remote_ratio']
fig = make_subplots(rows=1, cols=4)
 
for i, col in enumerate(cols):
    fig.add_trace(go.Histogram(x=df[col], nbinsx=20, name=f'Distribución de {col}'), row=1, col=i+1, )
 
fig.update_layout(height=500, width=1200, title_text="Distribución de Variables", showlegend=True)
fig.show()

# %% [markdown]
# #### Crea una gráfica para visualizar nuestras variables categóricas:

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(24, 12))
cols = ['experience_level', 'employment_type', 'job_title', 'salary_currency', 'employee_residence', 'company_size']

for i, column in enumerate(cols):
    row = i // 3
    col = i % 3
    sns.countplot(data=df, x=column, ax=axes[row, col])
    axes[row, col].set_title(f'Distribución de {column}')
    axes[row, col].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Identifica los outliers de nuestro dataset de forma gráfica:

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(24, 6))
cols = ['work_year', 'salary', 'salary_in_usd', 'remote_ratio']

for i, col in enumerate(cols):
    sns.boxplot(x=col, data=df, ax=axes[i])
    axes[i].set_title(f"Outliers {col}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Segundo paso, la visualización y el análisis de datos de forma gráfica y atractiva:

# %% [markdown]
# Una vez que hemos limpiado y preparado nuestros datos, estamos listos para comenzar a explorarlos y visualizarlos. Si no se nos ha proporcionado un objetivo específico para nuestro análisis, es muy útil formular preguntas sobre nuestros datos. Estas preguntas guiarán nuestras visualizaciones y análisis, y nos ayudarán a descubrir patrones, tendencias e información valiosa.

# %% [markdown]
# #### Preguntas a resolver usando las librerías de creaciones gráficas vistas en clase:

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ¿Cuál es el salario promedio por nivel de experiencia?

# %%
promedio_por_nivel = df.groupby('experience_level')['salary_in_usd'].mean().reset_index()
fig = px.bar(promedio_por_nivel, x="salary_in_usd", y="experience_level", template='plotly_dark') 
fig.show()

# %%
promedio_por_nivel = df.groupby('experience_level')['salary_in_usd'].mean().reset_index()
fig = px.pie(promedio_por_nivel, values='salary_in_usd', names='experience_level',template="plotly_dark",title='Salario medio por nivel de experiencia') 
fig.update_layout(width=800, height=600)
fig.show()

# %% [markdown]
# ¿Cómo ha cambiado el salario medio con el paso del tiempo (work_year)?

# %%
promedio_por_nivel = df.groupby('work_year')['salary_in_usd'].mean().reset_index()
promedio_por_nivel['work_year'] = pd.to_datetime(promedio_por_nivel['work_year'], format='%Y')
fig = px.bar(promedio_por_nivel, x="work_year", y="salary_in_usd", title='Salario medio por año', template="plotly_dark") #Podemos adatpar el fondo del gráfico mediante el uso de templates.
fig.show()

# %% [markdown]
# ¿Cuál es la proporción de trabajo remoto entre diferentes roles de trabajo?

# %%
average_remote_ratio_per_job = df.groupby('job_title')['remote_ratio'].mean().reset_index()

fig = px.bar(average_remote_ratio_per_job, x='job_title', y='remote_ratio', 
             title='Proporción media de trabajo remoto por tipo de trabajo', 
             template="plotly_dark", 
             orientation='v')
fig.show()

# %% [markdown]
# ¿Existe una relación entre el tamaño de la empresa y el salario?

# %%
fig = px.scatter(df, x='company_size', y='salary_in_usd', 
                 title='Relación entre el tamaño de la empresa y el salario',
                 template="plotly_dark", color='company_size',
                 category_orders={"company_size": ["S", "M", "L"]})

fig.show()

# %%
#Esta mejor
fig = px.violin(df, x='company_size', y='salary_in_usd', 
                title='Distribución de salarios por tamaño de empresa',
                template="plotly_dark", color='company_size',
                category_orders={"company_size": ["S", "M", "L"]})

fig.show()

# %% [markdown]
# ¿Cuál es el país con más trabajadores remotos?

# %%
remote_work_by_country = df.groupby('employee_residence')['remote_ratio'].sum().reset_index()
remote_work_by_country_sorted = remote_work_by_country.sort_values('remote_ratio', ascending=False)

top_15_countries = remote_work_by_country_sorted.head(15)

fig = px.bar(top_15_countries, x='employee_residence', y='remote_ratio', 
             title='15 países con más trabajadores remotos', 
             template='plotly_dark')

fig.update_xaxes(tickangle=45)

fig.show()

# %% [markdown]
# ¿Cómo ha cambiado la proporción de trabajo remoto con el paso del tiempo?

# %%
remote = df.groupby('work_year')['remote_ratio'].mean().reset_index()

fig = px.line(remote, x='work_year', y='remote_ratio', 
              title='Evolución del teletrabajo con el paso del tiempo', template="plotly_dark", color_discrete_sequence=['red'])

fig.show()

# %%
#Aquí lo intentamos con un filtrado del 100% remoto

remote_100 = df.query('remote_ratio == 100').groupby('work_year')['remote_ratio'].mean().reset_index()

fig = px.line(remote_100, x='work_year', y='remote_ratio', 
              title='Evolución del teletrabajo con el paso del tiempo', template="plotly_dark", color_discrete_sequence=['red'])

fig.show()

# %% [markdown]
# ¿Cuál es el país con los salarios promedio más altos en USD?

# %%
# Supongamos que tienes un DataFrame 'df' con los datos proporcionados

# Calcular el salario promedio en USD por país
salario_promedio_por_pais = df.groupby('employee_residence')['salary_in_usd'].mean().reset_index()

# Ordenar los países por salario promedio en orden descendente
salario_promedio_por_pais = salario_promedio_por_pais.sort_values(by='salary_in_usd', ascending=False)

# Tomar solo los primeros N países con los salarios promedio más altos en USD
N = 15  # Aquí puedes ajustar el número de países que quieres mostrar
salario_promedio_top_N = salario_promedio_por_pais.head(N)

# Crear el gráfico de barras polares
fig = px.bar_polar(salario_promedio_top_N, r='salary_in_usd', theta='employee_residence', 
                   title=f'Los {N} países con los salarios promedio más altos en USD', 
                   template='plotly_dark',
                   color='salary_in_usd',
                   color_continuous_scale='Viridis')
fig.update_layout(
    width=800,  # Ancho del gráfico
    height=600, # Altura del gráfico
)

# Mostrar el gráfico
fig.show()

# %%
pd.set_option('display.max_rows', None)
df['company_location']
# Out:
# 0       ES
# 1       US
# 2       US
# 3       CA
# 4       CA
# 5       US
# 6       US
# 7       CA
# 8       CA
# 9       US
# 10      US
# 11      US
# 12      US
# 13      US
# 14      US
# 15      US
# 16      US
# 17      US
# 18      US
# 19      US
# 20      US
# 21      DE
# 22      DE
# 23      GB
# 24      GB
# 25      US
# 26      US
# 27      US
# 28      US
# 29      CA
# 30      CA
# 31      US
# 32      US
# 33      US
# 34      US
# 35      US
# 36      US
# 37      US
# 38      US
# 39      NG
# 40      NG
# 41      IN
# 42      US
# 43      US
# 44      US
# 45      US
# 46      US
# 47      US
# 48      US
# 49      US
# 50      US
# 51      US
# 52      US
# 53      US
# 54      US
# 55      US
# 56      US
# 57      US
# 58      US
# 59      US
# 60      US
# 61      US
# 62      US
# 63      US
# 64      US
# 65      US
# 66      US
# 67      US
# 68      US
# 69      US
# 70      US
# 71      US
# 72      US
# 73      US
# 74      US
# 75      US
# 76      US
# 77      US
# 78      US
# 79      US
# 80      HK
# 81      US
# 82      DE
# 83      IN
# 84      NL
# 85      US
# 86      US
# 87      US
# 88      US
# 89      US
# 90      US
# 91      ES
# 92      ES
# 93      US
# 94      US
# 95      US
# 96      US
# 97      US
# 98      US
# 99      US
# 100     US
# 101     US
# 102     US
# 103     US
# 104     US
# 105     US
# 106     US
# 107     US
# 108     US
# 109     US
# 110     US
# 111     US
# 112     US
# 113     US
# 114     CH
# 115     US
# 116     US
# 117     US
# 118     US
# 119     US
# 120     US
# 121     US
# 122     US
# 123     US
# 124     US
# 125     US
# 126     US
# 127     US
# 128     US
# 129     US
# 130     US
# 131     US
# 132     US
# 133     US
# 134     US
# 135     US
# 136     US
# 137     US
# 138     US
# 139     US
# 140     US
# 141     US
# 142     US
# 143     US
# 144     US
# 145     US
# 146     US
# 147     US
# 148     US
# 149     US
# 150     US
# 151     US
# 152     US
# 153     US
# 154     US
# 155     US
# 156     IN
# 157     GB
# 158     GB
# 159     US
# 160     US
# 161     US
# 162     US
# 163     US
# 164     US
# 165     US
# 166     US
# 167     US
# 168     US
# 169     US
# 170     US
# 171     US
# 172     US
# 173     US
# 174     US
# 175     CF
# 176     CF
# 177     US
# 178     US
# 179     US
# 180     US
# 181     GB
# 182     GB
# 183     CA
# 184     GB
# 185     GB
# 186     US
# 187     US
# 188     US
# 189     US
# 190     US
# 191     US
# 192     US
# 193     US
# 194     US
# 195     US
# 196     US
# 197     US
# 198     US
# 199     US
# 200     US
# 201     US
# 202     FR
# 203     US
# 204     US
# 205     US
# 206     US
# 207     US
# 208     US
# 209     US
# 210     US
# 211     US
# 212     US
# 213     CA
# 214     CA
# 215     US
# 216     US
# 217     IN
# 218     FI
# 219     FI
# 220     US
# 221     US
# 222     US
# 223     US
# 224     US
# 225     US
# 226     US
# 227     US
# 228     US
# 229     US
# 230     US
# 231     US
# 232     US
# 233     US
# 234     US
# 235     US
# 236     US
# 237     US
# 238     US
# 239     US
# 240     US
# 241     US
# 242     US
# 243     US
# 244     US
# 245     US
# 246     US
# 247     US
# 248     US
# 249     GB
# 250     US
# 251     US
# 252     US
# 253     US
# 254     US
# 255     US
# 256     US
# 257     US
# 258     US
# 259     US
# 260     US
# 261     US
# 262     US
# 263     US
# 264     ES
# 265     ES
# 266     US
# 267     US
# 268     US
# 269     US
# 270     US
# 271     US
# 768     SI
# 769     GB
# 770     GB
# 771     GB
# 772     GB
# 773     US
# 774     US
# 775     US
# 776     US
# 777     US
# 778     US
# 779     CA
# 780     CA
# 781     US
# 782     US
# 783     US
# 784     US
# 785     US
# 786     US
# 787     US
# 788     US
# 789     US
# 790     US
# 791     US
# 792     US
# 793     US
# 794     US
# 795     US
# 796     US
# 797     US
# 798     US
# 799     US
# 800     US
# 801     US
# 802     US
# 803     CA
# 804     CA
# 805     DE
# 806     US
# 807     US
# 808     US
# 809     US
# 810     US
# 811     US
# 812     US
# 813     US
# 814     US
# 815     US
# 816     US
# 817     US
# 818     US
# 819     US
# 820     US
# 821     US
# 822     US
# 823     US
# 824     US
# 825     US
# 826     US
# 827     US
# 828     US
# 829     US
# 830     US
# 831     US
# 832     US
# 833     US
# 834     US
# 835     US
# 836     DE
# 837     MX
# 838     MX
# 839     US
# 840     US
# 841     US
# 842     US
# 843     US
# 844     US
# 845     US
# 846     US
# 847     US
# 848     US
# 849     US
# 850     US
# 851     FR
# 852     US
# 853     US
# 854     US
# 855     US
# 856     AU
# 857     US
# 858     US
# 859     US
# 860     US
# 861     US
# 862     US
# 863     US
# 864     US
# 865     US
# 866     US
# 867     US
# 868     US
# 869     US
# 870     US
# 871     US
# 872     US
# 873     US
# 874     US
# 875     US
# 876     GB
# 877     GB
# 878     US
# 879     US
# 880     US
# 881     US
# 882     US
# 883     US
# 884     US
# 885     US
# 886     US
# 887     US
# 888     US
# 889     US
# 890     US
# 891     US
# 892     US
# 893     US
# 894     US
# 895     US
# 896     US
# 897     US
# 898     US
# 899     US
# 900     US
# 901     US
# 902     US
# 903     US
# 904     US
# 905     US
# 906     US
# 907     US
# 908     US
# 909     US
# 910     US
# 911     US
# 912     US
# 913     US
# 914     US
# 915     US
# 916     GB
# 917     GB
# 918     US
# 919     US
# 920     US
# 921     US
# 922     US
# 923     US
# 924     US
# 925     US
# 926     US
# 927     US
# 928     US
# 929     US
# 930     US
# 931     US
# 932     GB
# 933     GB
# 934     US
# 935     US
# 936     US
# 937     US
# 938     US
# 939     US
# 940     US
# 941     US
# 942     US
# 943     US
# 944     US
# 945     US
# 946     US
# 947     US
# 948     US
# 949     US
# 950     US
# 951     US
# 952     US
# 953     US
# 954     US
# 955     US
# 956     US
# 957     US
# 958     US
# 959     US
# 960     US
# 961     US
# 962     US
# 963     US
# 964     ES
# 965     ES
# 966     US
# 967     US
# 968     IN
# 969     US
# 970     US
# 971     US
# 972     BR
# 973     PT
# 974     RU
# 975     US
# 976     US
# 977     US
# 978     US
# 979     MX
# 980     MX
# 981     US
# 982     US
# 983     US
# 984     DE
# 985     DE
# 986     US
# 987     US
# 988     IN
# 989     US
# 990     US
# 991     US
# 992     US
# 993     US
# 994     US
# 995     US
# 996     US
# 997     FR
# 998     TH
# 999     US
# 1000    US
# 1001    US
# 1002    US
# 1003    US
# 1004    US
# 1005    US
# 1006    US
# 1007    US
# 1008    US
# 1009    US
# 1010    US
# 1011    US
# 1012    US
# 2499    US
# 2500    US
# 2501    US
# 2502    US
# 2503    US
# 2504    US
# 2505    US
# 2506    US
# 2507    US
# 2508    US
# 2509    US
# 2510    US
# 2511    US
# 2512    US
# 2513    US
# 2514    US
# 2515    US
# 2516    US
# 2517    US
# 2518    US
# 2519    US
# 2520    US
# 2521    US
# 2522    US
# 2523    US
# 2524    US
# 2525    US
# 2526    US
# 2527    US
# 2528    US
# 2529    US
# 2530    US
# 2531    US
# 2532    US
# 2533    US
# 2534    US
# 2535    US
# 2536    US
# 2537    US
# 2538    ES
# 2539    ES
# 2540    US
# 2541    US
# 2542    US
# 2543    US
# 2544    US
# 2545    US
# 2546    MX
# 2547    BR
# 2548    BR
# 2549    US
# 2550    US
# 2551    US
# 2552    US
# 2553    BR
# 2554    BR
# 2555    US
# 2556    US
# 2557    US
# 2558    US
# 2559    BR
# 2560    BR
# 2561    US
# 2562    US
# 2563    US
# 2564    US
# 2565    US
# 2566    US
# 2567    BR
# 2568    BR
# 2569    US
# 2570    GB
# 2571    CA
# 2572    US
# 2573    GB
# 2574    US
# 2575    US
# 2576    US
# 2577    US
# 2578    IN
# 2579    AU
# 2580    US
# 2581    US
# 2582    US
# 2583    US
# 2584    US
# 2585    US
# 2586    US
# 2587    US
# 2588    US
# 2589    SG
# 2590    US
# 2591    US
# 2592    US
# 2593    US
# 2594    US
# 2595    US
# 2596    GB
# 2597    GB
# 2598    US
# 2599    US
# 2600    US
# 2601    US
# 2602    US
# 2603    US
# 2604    US
# 2605    US
# 2606    US
# 2607    US
# 2608    US
# 2609    US
# 2610    US
# 2611    US
# 2612    US
# 2613    US
# 2614    US
# 2615    US
# 2616    US
# 2617    US
# 2618    US
# 2619    US
# 2620    US
# 2621    US
# 2622    US
# 2623    US
# 2624    US
# 2625    US
# 2626    US
# 2627    US
# 2628    US
# 2629    US
# 2630    US
# 2631    US
# 2632    US
# 2633    US
# 2634    US
# 2635    US
# 2636    US
# 2637    US
# 2638    US
# 2639    US
# 2640    US
# 2641    US
# 2642    US
# 2643    US
# 2644    ES
# 2645    ES
# 2646    US
# 2647    US
# 2648    US
# 2649    US
# 2650    US
# 2651    CA
# 2652    US
# 2653    US
# 2654    AU
# 2655    IN
# 2656    PT
# 2657    PT
# 2658    US
# 2659    US
# 2660    US
# 2661    US
# 2662    US
# 2663    US
# 2664    US
# 2665    CA
# 2666    US
# 2667    US
# 2668    US
# 2669    US
# 2670    US
# 2671    US
# 2672    US
# 2673    US
# 2674    US
# 2675    US
# 2676    ES
# 2677    ES
# 2678    DE
# 2679    US
# 2680    NG
# 2681    US
# 2682    US
# 2683    PT
# 2684    CZ
# 2685    US
# 2686    DE
# 2687    DE
# 2688    US
# 2689    US
# 2690    US
# 2691    US
# 2692    US
# 2693    US
# 2694    US
# 2695    US
# 2696    US
# 2697    US
# 2698    AU
# 2699    AU
# 2700    US
# 2701    US
# 2702    US
# 2703    US
# 2704    CA
# 2705    CA
# 2706    US
# 2707    US
# 2708    US
# 2709    US
# 2710    US
# 2711    US
# 2712    TR
# 2713    US
# 2714    US
# 2715    US
# 2716    US
# 2717    US
# 2718    US
# 2719    US
# 2720    US
# 2721    US
# 2722    US
# 2723    US
# 2724    US
# 2725    US
# 2726    US
# 2727    US
# 2728    US
# 2729    US
# 2730    US
# 2731    US
# 2732    US
# 2733    US
# 2734    US
# 2735    US
# 2736    US
# 2737    US
# 2738    US
# 2739    US
# 2740    US
# 2741    US
# 2742    US
# 2743    US
# 2744    US
# 2745    US
# 2746    US
# 2747    US
# 2748    US
# 2749    US
# 2750    US
# 2751    US
# 2752    US
# 2753    US
# 2754    US
# 2755    US
# 2756    US
# 2757    US
# 2758    US
# 2759    US
# 2760    US
# 2761    US
# 2762    PR
# 2763    PR
# 2764    US
# 2765    US
# 2766    US
# 2767    US
# 2768    US
# 2769    US
# 2770    US
# 2771    US
# 2772    US
# 2773    US
# 2774    US
# 2775    US
# 2776    US
# 2777    US
# 2778    GB
# 2779    GB
# 2780    US
# 2781    US
# 2782    ES
# 2783    ES
# 2784    US
# 2785    GB
# 2786    IN
# 2787    US
# 2788    US
# 2789    ES
# 2790    US
# 2791    US
# 2792    US
# 2793    US
# 2794    US
# 2795    US
# 2796    US
# 2797    US
# 2798    US
# 2799    US
# 2800    IN
# 2801    US
# 2802    US
# 2803    US
# 2804    US
# 2805    US
# 2806    FI
# 2807    AS
# 2808    US
# 2809    US
# 2810    GB
# 2811    GB
# 2812    US
# 2813    US
# 2814    US
# 2815    US
# 2816    US
# 2817    US
# 2818    US
# 2819    FR
# 2820    US
# 2821    US
# 2822    US
# 2823    US
# 2824    US
# 2825    US
# 2826    US
# 2827    US
# 2828    US
# 2829    US
# 2830    US
# 2831    US
# 2832    US
# 2833    US
# 2834    TH
# 2835    US
# 2836    US
# 2837    US
# 2838    US
# 2839    US
# 2840    BR
# 2841    US
# 2842    US
# 2843    US
# 2844    US
# 2845    US
# 2846    US
# 2847    US
# 2848    US
# 2849    FR
# 2850    US
# 2851    US
# 2852    US
# 2853    US
# 2854    US
# 2855    US
# 2856    US
# 2857    US
# 2858    US
# 2859    US
# 2860    US
# 2861    US
# 2862    GB
# 2863    US
# 2864    US
# 2865    US
# 2866    US
# 2867    US
# 2868    US
# 2869    US
# 2870    NL
# 2871    DE
# 2872    IN
# 2873    US
# 2874    US
# 2875    US
# 2876    US
# 2877    US
# 2878    US
# 2879    US
# 2880    US
# 2881    US
# 2882    US
# 2883    US
# 2884    US
# 2885    US
# 2886    US
# 2887    US
# 2888    GR
# 2889    GR
# 2890    GB
# 2891    GB
# 2892    ES
# 2893    ES
# 2894    US
# 2895    US
# 2896    US
# 2897    US
# 2898    GB
# 2899    GB
# 2900    US
# 2901    US
# 2902    GB
# 2903    GB
# 2904    US
# 2905    US
# 2906    US
# 2907    US
# 2908    US
# 2909    ES
# 2910    US
# 2911    US
# 2912    US
# 2913    US
# 2914    US
# 2915    US
# 2916    US
# 2917    US
# 2918    US
# 2919    US
# 2920    US
# 2921    GB
# 2922    GB
# 2923    DK
# 2924    US
# 2925    US
# 2926    US
# 2927    US
# 2928    US
# 2929    US
# 2930    US
# 2931    US
# 2932    US
# 2933    BO
# 2934    US
# 2935    US
# 2936    US
# 2937    US
# 2938    US
# 2939    PH
# 2940    AU
# 2941    US
# 2942    US
# 2943    PT
# 2944    US
# 2945    US
# 2946    US
# 2947    US
# 2948    US
# 2949    US
# 2950    US
# 2951    US
# 2952    US
# 2953    US
# 2954    US
# 2955    NL
# 2956    CA
# 2957    CA
# 2958    US
# 2959    US
# 2960    US
# 2961    US
# 2962    US
# 2963    US
# 2964    US
# 2965    US
# 2966    IN
# 2967    GB
# 2968    US
# 2969    FR
# 2970    US
# 2971    US
# 2972    US
# 2973    US
# 2974    US
# 2975    BR
# 2976    US
# 2977    US
# 2978    US
# 2979    US
# 2980    US
# 2981    US
# 2982    US
# 2983    US
# 2984    NL
# 2985    NL
# 2986    US
# 2987    US
# 2988    US
# 2989    US
# 2990    US
# 2991    US
# 2992    US
# 2993    US
# 2994    US
# 2995    US
# 2996    US
# 2997    US
# 2998    US
# 2999    US
# 3000    US
# 3001    US
# 3002    US
# 3003    US
# 3004    US
# 3005    US
# 3006    GB
# 3007    GB
# 3008    US
# 3009    US
# 3010    PR
# 3011    PR
# 3012    US
# 3013    US
# 3014    GB
# 3015    GB
# 3016    GB
# 3017    US
# 3018    US
# 3019    US
# 3020    US
# 3021    US
# 3022    US
# 3023    IN
# 3024    US
# 3025    US
# 3026    DE
# 3027    US
# 3028    US
# 3029    US
# 3030    US
# 3031    US
# 3032    US
# 3033    AR
# 3034    BE
# 3035    GB
# 3036    US
# 3037    US
# 3038    US
# 3039    US
# 3040    US
# 3041    US
# 3042    US
# 3043    US
# 3044    US
# 3045    US
# 3046    US
# 3047    US
# 3048    US
# 3049    US
# 3050    US
# 3051    US
# 3052    US
# 3053    US
# 3054    US
# 3055    US
# 3056    US
# 3057    US
# 3058    US
# 3059    US
# 3060    IN
# 3061    ID
# 3062    AT
# 3063    US
# 3064    NL
# 3065    GB
# 3066    US
# 3067    US
# 3068    US
# 3069    US
# 3070    US
# 3071    US
# 3072    US
# 3073    GB
# 3074    BE
# 3075    IN
# 3076    US
# 3077    US
# 3078    US
# 3079    US
# 3080    US
# 3081    US
# 3082    US
# 3083    US
# 3084    US
# 3085    US
# 3086    US
# 3087    US
# 3088    US
# 3089    US
# 3090    US
# 3091    US
# 3092    US
# 3093    GB
# 3094    FR
# 3095    GB
# 3096    GB
# 3097    DE
# 3098    US
# 3099    US
# 3100    US
# 3101    US
# 3102    GB
# 3103    US
# 3104    US
# 3105    US
# 3106    US
# 3107    US
# 3108    US
# 3109    US
# 3110    US
# 3111    US
# 3112    US
# 3113    GB
# 3114    GB
# 3115    US
# 3116    US
# 3117    US
# 3118    US
# 3119    IN
# 3120    IN
# 3121    US
# 3122    US
# 3123    US
# 3124    TR
# 3125    SG
# 3126    US
# 3127    US
# 3128    US
# 3129    US
# 3130    US
# 3131    US
# 3132    US
# 3133    EG
# 3134    US
# 3135    US
# 3136    US
# 3137    US
# 3138    PT
# 3139    ID
# 3140    US
# 3141    US
# 3142    AU
# 3143    US
# 3144    GB
# 3145    GB
# 3146    US
# 3147    US
# 3148    US
# 3149    US
# 3150    US
# 3151    US
# 3152    US
# 3153    US
# 3154    DE
# 3155    US
# 3156    GB
# 3157    GB
# 3158    US
# 3159    US
# 3160    US
# 3161    US
# 3162    US
# 3163    DE
# 3164    GB
# 3165    GB
# 3166    US
# 3167    US
# 3168    US
# 3169    US
# 3170    US
# 3171    US
# 3172    US
# 3173    US
# 3174    DE
# 3175    US
# 3176    US
# 3177    US
# 3178    US
# 3179    US
# 3180    US
# 3181    GR
# 3182    GR
# 3183    CA
# 3184    US
# 3185    US
# 3186    US
# 3187    US
# 3188    US
# 3189    US
# 3190    US
# 3191    US
# 3192    IN
# 3193    GB
# 3194    US
# 3195    US
# 3196    GB
# 3197    GB
# 3198    ES
# 3199    ES
# 3200    ES
# 3201    ES
# 3202    GB
# 3203    GB
# 3204    GR
# 3205    GR
# 3206    US
# 3207    US
# 3208    GR
# 3209    GR
# 3210    GB
# 3211    GB
# 3212    US
# 3213    US
# 3214    ES
# 3215    ES
# 3216    US
# 3217    US
# 3218    GB
# 3219    GB
# 3220    GR
# 3221    GR
# 3222    GB
# 3223    GB
# 3224    IT
# 3225    MX
# 3226    US
# 3227    US
# 3228    US
# 3229    US
# 3230    US
# 3231    US
# 3232    US
# 3233    US
# 3234    US
# 3235    US
# 3236    US
# 3237    US
# 3238    US
# 3239    US
# 3240    GB
# 3241    GB
# 3242    GB
# 3243    GB
# 3244    US
# 3245    US
# 3246    US
# 3247    US
# 3248    US
# 3249    US
# 3250    US
# 3251    US
# 3252    US
# 3253    US
# 3254    US
# 3255    US
# 3256    US
# 3257    US
# 3258    US
# 3259    US
# 3260    US
# 3261    US
# 3262    US
# 3263    US
# 3264    US
# 3265    US
# 3266    US
# 3267    US
# 3268    GB
# 3269    GB
# 3270    US
# 3271    US
# 3272    GB
# 3273    GB
# 3274    US
# 3275    US
# 3276    US
# 3277    US
# 3278    US
# 3279    US
# 3280    US
# 3281    US
# 3282    GB
# 3283    GB
# 3284    US
# 3285    US
# 3286    CA
# 3287    CA
# 3288    CA
# 3289    CA
# 3290    CA
# 3291    CA
# 3292    US
# 3293    US
# 3294    US
# 3295    US
# 3296    US
# 3297    US
# 3298    US
# 3299    US
# 3300    US
# 3301    US
# 3302    US
# 3303    US
# 3304    US
# 3305    US
# 3306    US
# 3307    US
# 3308    US
# 3309    US
# 3310    US
# 3311    US
# 3312    US
# 3313    US
# 3314    US
# 3315    US
# 3316    US
# 3317    US
# 3318    US
# 3319    US
# 3320    US
# 3321    US
# 3322    US
# 3323    US
# 3324    US
# 3325    US
# 3326    US
# 3327    US
# 3328    US
# 3329    US
# 3330    US
# 3331    US
# 3332    US
# 3333    US
# 3334    US
# 3335    US
# 3336    US
# 3337    US
# 3338    CA
# 3339    CA
# 3340    US
# 3341    US
# 3342    US
# 3343    US
# 3344    US
# 3345    US
# 3346    US
# 3347    US
# 3348    US
# 3349    US
# 3350    US
# 3351    US
# 3352    US
# 3353    US
# 3354    GB
# 3355    GB
# 3356    US
# 3357    US
# 3358    US
# 3359    US
# 3360    US
# 3361    US
# 3362    US
# 3363    US
# 3364    US
# 3365    US
# 3366    US
# 3367    US
# 3368    CA
# 3369    CA
# 3370    US
# 3371    US
# 3372    US
# 3373    US
# 3374    US
# 3375    US
# 3376    US
# 3377    US
# 3378    US
# 3379    US
# 3380    US
# 3381    US
# 3382    US
# 3383    US
# 3384    US
# 3385    US
# 3386    US
# 3387    US
# 3388    US
# 3389    US
# 3390    US
# 3391    US
# 3392    US
# 3393    US
# 3394    US
# 3395    US
# 3396    US
# 3397    US
# 3398    US
# 3399    US
# 3400    US
# 3401    US
# 3402    GB
# 3403    GB
# 3404    US
# 3405    US
# 3406    US
# 3407    US
# 3408    AE
# 3409    AE
# 3410    US
# 3411    US
# 3412    US
# 3413    US
# 3414    US
# 3415    US
# 3416    US
# 3417    US
# 3418    CA
# 3419    CA
# 3420    CA
# 3421    US
# 3422    IN
# 3423    IN
# 3424    PT
# 3425    DE
# 3426    IN
# 3427    US
# 3428    US
# 3429    CA
# 3430    US
# 3431    IE
# 3432    US
# 3433    CA
# 3434    LU
# 3435    GR
# 3436    SI
# 3437    US
# 3438    CA
# 3439    US
# 3440    US
# 3441    US
# 3442    AU
# 3443    MY
# 3444    EE
# 3445    NL
# 3446    DE
# 3447    FR
# 3448    AU
# 3449    US
# 3450    US
# 3451    US
# 3452    CA
# 3453    PL
# 3454    CA
# 3455    HN
# 3456    CZ
# 3457    CZ
# 3458    DE
# 3459    AT
# 3460    US
# 3461    US
# 3462    US
# 3463    US
# 3464    US
# 3465    US
# 3466    US
# 3467    US
# 3468    US
# 3469    CH
# 3470    US
# 3471    FR
# 3472    US
# 3473    PK
# 3474    US
# 3475    JP
# 3476    JP
# 3477    AU
# 3478    US
# 3479    US
# 3480    US
# 3481    DZ
# 3482    US
# 3483    DE
# 3484    BR
# 3485    US
# 3486    US
# 3487    US
# 3488    FR
# 3489    IN
# 3490    US
# 3491    DE
# 3492    IN
# 3493    US
# 3494    IN
# 3495    US
# 3496    ES
# 3497    GB
# 3498    PT
# 3499    US
# 3500    US
# 3501    RO
# 3502    US
# 3503    IQ
# 3504    US
# 3505    BE
# 3506    DE
# 3507    FR
# 3508    GB
# 3509    US
# 3510    US
# 3511    US
# 3512    US
# 3513    US
# 3514    US
# 3515    DE
# 3516    DE
# 3517    US
# 3518    RU
# 3519    RU
# 3520    US
# 3521    US
# 3522    US
# 3523    FR
# 3524    AT
# 3525    CA
# 3526    US
# 3527    UA
# 3528    CA
# 3529    US
# 3530    US
# 3531    US
# 3532    US
# 3533    US
# 3534    US
# 3535    NG
# 3536    US
# 3537    IN
# 3538    US
# 3539    CA
# 3540    ES
# 3541    PL
# 3542    PL
# 3543    US
# 3544    GB
# 3545    US
# 3546    FR
# 3547    US
# 3548    NG
# 3549    US
# 3550    US
# 3551    DE
# 3552    US
# 3553    US
# 3554    US
# 3555    US
# 3556    FR
# 3557    US
# 3558    US
# 3559    ES
# 3560    US
# 3561    DE
# 3562    PT
# 3563    DK
# 3564    GB
# 3565    GB
# 3566    DE
# 3567    IN
# 3568    US
# 3569    US
# 3570    CA
# 3571    GB
# 3572    US
# 3573    GB
# 3574    US
# 3575    US
# 3576    DE
# 3577    US
# 3578    US
# 3579    GB
# 3580    SG
# 3581    IN
# 3582    US
# 3583    US
# 3584    US
# 3585    US
# 3586    US
# 3587    US
# 3588    US
# 3589    IN
# 3590    PT
# 3591    US
# 3592    FR
# 3593    IN
# 3594    MX
# 3595    US
# 3596    GB
# 3597    TR
# 3598    FR
# 3599    GB
# 3600    US
# 3601    CA
# 3602    US
# 3603    US
# 3604    CA
# 3605    IN
# 3606    NL
# 3607    AE
# 3608    CA
# 3609    JP
# 3610    US
# 3611    US
# 3612    US
# 3613    GB
# 3614    US
# 3615    US
# 3616    US
# 3617    DE
# 3618    US
# 3619    US
# 3620    NL
# 3621    CN
# 3622    US
# 3623    US
# 3624    TR
# 3625    ES
# 3626    US
# 3627    US
# 3628    FR
# 3629    DE
# 3630    DE
# 3631    US
# 3632    US
# 3633    DE
# 3634    TR
# 3635    US
# 3636    US
# 3637    US
# 3638    DE
# 3639    IN
# 3640    IN
# 3641    DE
# 3642    US
# 3643    DE
# 3644    IN
# 3645    CA
# 3646    HU
# 3647    US
# 3648    DE
# 3649    US
# 3650    IN
# 3651    KE
# 3652    US
# 3653    CA
# 3654    US
# 3655    US
# 3656    CO
# 3657    NZ
# 3658    FR
# 3659    IN
# 3660    ES
# 3661    GB
# 3662    FR
# 3663    US
# 3664    US
# 3665    DE
# 3666    IN
# 3667    US
# 3668    US
# 3669    CL
# 3670    US
# 3671    AT
# 3672    US
# 3673    ES
# 3674    US
# 3675    US
# 3676    CA
# 3677    GB
# 3678    IN
# 3679    GB
# 3680    PL
# 3681    PK
# 3682    JP
# 3683    GB
# 3684    BE
# 3685    IN
# 3686    US
# 3687    DK
# 3688    DE
# 3689    IN
# 3690    GR
# 3691    US
# 3692    GB
# 3693    FR
# 3694    SI
# 3695    US
# 3696    US
# 3697    US
# 3698    US
# 3699    DK
# 3700    US
# 3701    US
# 3702    GR
# 3703    BR
# 3704    US
# 3705    CH
# 3706    FR
# 3707    US
# 3708    DE
# 3709    DE
# 3710    IT
# 3711    US
# 3712    US
# 3713    US
# 3714    CA
# 3715    GB
# 3716    PK
# 3717    GB
# 3718    JP
# 3719    FR
# 3720    MD
# 3721    US
# 3722    US
# 3723    BR
# 3724    LU
# 3725    DE
# 3726    DE
# 3727    ES
# 3728    ES
# 3729    AS
# 3730    AT
# 3731    LU
# 3732    US
# 3733    US
# 3734    IN
# 3735    US
# 3736    US
# 3737    US
# 3738    US
# 3739    NL
# 3740    US
# 3741    US
# 3742    US
# 3743    US
# 3744    HR
# 3745    JP
# 3746    IL
# 3747    US
# 3748    MT
# 3749    US
# 3750    US
# 3751    US
# 3752    US
# 3753    US
# 3754    IN
# Name: company_location, dtype: object

# %%
df['company_location'] = df['company_location'].str.strip()

print(df['company_location'].unique())
# Out:
# ['ES' 'US' 'CA' 'DE' 'GB' 'NG' 'IN' 'HK' 'NL' 'CH' 'CF' 'FR' 'FI' 'UA'
#  'IE' 'IL' 'GH' 'CO' 'SG' 'AU' 'SE' 'SI' 'MX' 'BR' 'PT' 'RU' 'TH' 'HR'
#  'VN' 'EE' 'AM' 'BA' 'KE' 'GR' 'MK' 'LV' 'RO' 'PK' 'IT' 'MA' 'PL' 'AL'
#  'AR' 'LT' 'AS' 'CR' 'IR' 'BS' 'HU' 'AT' 'SK' 'CZ' 'TR' 'PR' 'DK' 'BO'
#  'PH' 'BE' 'ID' 'EG' 'AE' 'LU' 'MY' 'HN' 'JP' 'DZ' 'IQ' 'CN' 'NZ' 'CL'
#  'MD' 'MT']

# %% [markdown]
# ¿Cómo se distribuyen los roles de trabajo en las diferentes categorías de experiencia?

# %%
experience_job_ds = df.groupby(['experience_level', 'job_title']).size().reset_index(name='Count')

fig = px.bar(experience_job_ds, x='experience_level', y='Count', color='job_title', 
             title="Recuento de trabajos por nivel de experiencia y título de trabajo", 
             template="plotly_dark", barmode='group')
fig.update_layout(
    width=1500,  
    height=700, 
)
fig.show()

# %% [markdown]
# ¿Cómo varía el salario promedio entre los diferentes tipos de empleo, fulltime, partime ect?

# %%
print(df['remote_ratio'].unique())
# Out:
# [100   0  50]

# %%
conteo = df['remote_ratio'].value_counts()

# Calcular el porcentaje de cada valor
porcentaje_valores = (conteo / len(df)) * 100

print(porcentaje_valores)
# Out:
# remote_ratio
# 0      51.211718
# 100    43.754993
# 50      5.033289
# Name: count, dtype: float64

# %%
porcentajes = df['remote_ratio'].value_counts(normalize=True) * 100
porcentajes.round(2)
# Out:
# remote_ratio
# 0      51.21
# 100    43.75
# 50      5.03
# Name: proportion, dtype: float64

# %%
fig = go.Figure()

fig.add_trace(go.Funnel(
    y=["FullTime", "PartTime", "In person"],
    x=[51.21, 43.75, 5.03 ],
    textinfo="value+percent total",  
    opacity=0.7,  
    marker={"color": ["deepskyblue", "lightsalmon","teal"]},  
    name="Salario promedio por tipo de trabajo"
))

fig.update_layout(
    title="Salario promedio por tipo de trabajo",
    template="plotly_dark",
    yaxis_title="Tipo de trabajo",
    xaxis_title="Número de trabajadores"
)
fig.show()

# %% [markdown]
# #### Crear un top10 con los empleos mas demandados:

# %% [markdown]
# ####  Crear un top10 con los empleos mas cotizados:

# %% [markdown]
# ####  Crear un top10 con empleos donde podemos trabajar remoto:

# %%
top10_remotos = df.groupby('job_title')['remote_ratio'].mean().reset_index()
fig = px.funnel(top10_remotos[:10].sort_values(by='remote_ratio', ascending=False), x='job_title', y='remote_ratio', 
                title='Top 10 de profesiones que más trabajo remoto tienen', color_discrete_sequence=['#4b8cff'], template="plotly_dark")
fig.show()
